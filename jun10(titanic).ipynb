# %%
import pandas as pd

# %%
data=pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.Age
# or data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data.Ticket
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: str

# %%
#from- used to import many packages from library
from matplotlib import pyplot as plt

# %%
plt.hist(data.Age)    #hist-calculates a numerical spectrum(continuous) of number to understand data distribution
plt.show        #approx measurements are marked
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.isnull().sum()   #isnull()- identifies null positions, sum()- counts
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.drop(columns=['PassengerId','Name','SibSp','Ticket','Fare'],inplace=True)     #drop()- removes data from original data and prints(not permanent)
data
#inplace=True - permanently removes the columns mentioned and requires calling
# Out:
#      Survived  Pclass     Sex   Age  Parch Cabin Embarked
# 0           0       3    male  22.0      0   NaN        S
# 1           1       1  female  38.0      0   C85        C
# 2           1       3  female  26.0      0   NaN        S
# 3           1       1  female  35.0      0  C123        S
# 4           0       3    male  35.0      0   NaN        S
# ..        ...     ...     ...   ...    ...   ...      ...
# 886         0       2    male  27.0      0   NaN        S
# 887         1       1  female  19.0      0   B42        S
# 888         0       3  female   NaN      2   NaN        S
# 889         1       1    male  26.0      0  C148        C
# 890         0       3    male  32.0      0   NaN        Q
#
# [891 rows x 7 columns]

# %%
data['Survived'].value_counts().plot(kind='bar')        #value_counts()- exact numbers are taken for ploting
plt.show()

# %%
plt.title('Pclass')
data['Pclass'].value_counts().plot(kind='bar')
plt.show()

plt.title('Sex')
data['Sex'].value_counts().plot(kind='bar')
plt.show()

plt.title('Age')
data['Age'].value_counts().plot(kind='bar')
plt.show()

plt.title('Parch')
data['Parch'].value_counts().plot(kind='bar')
plt.show()

plt.title('Cabin')
data['Cabin'].value_counts().plot(kind='bar')
plt.show()

plt.title('Embarked')
data['Embarked'].value_counts().plot(kind='bar')
plt.show()
